# %% [markdown]
# Question 1 matplot is data ploting library for python
#
# five plot--
#
# bar
#
# histogram
#
# pie chart
#
# boxplot
#
# line plot

# %% [markdown]
# Question 2

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("scatter plot")

# %% [markdown]
# Question 3

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

fig, axs = plt.subplots(2, 2, figsize=(12, 12))

axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Plot 1')

axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Plot 2')

axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Plot 3')

axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Plot 4')

plt.tight_layout()

plt.show()

# %% [markdown]
# Question 4

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.show()

# %% [markdown]
# Question 5

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b0842c88ee0>,
#   <matplotlib.lines.Line2D at 0x7b0842c88eb0>,
#   <matplotlib.lines.Line2D at 0x7b0842c8a380>,
#   <matplotlib.lines.Line2D at 0x7b0842c8baf0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b0842c8b610>,
#   <matplotlib.lines.Line2D at 0x7b0842c88e50>,
#   <matplotlib.lines.Line2D at 0x7b0842c8ba60>,
#   <matplotlib.lines.Line2D at 0x7b0842c89630>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b0842c8b8b0>,
#   <matplotlib.lines.Line2D at 0x7b0842c896c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b0844edd660>,
#   <matplotlib.lines.Line2D at 0x7b0842c8b910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b0844e63610>,
#   <matplotlib.lines.Line2D at 0x7b0844baeef0>],
#  'means': []}
